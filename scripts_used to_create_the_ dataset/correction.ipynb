# %%
import pandas as pd

# %%
df_deprem = pd.read_csv('deprem.csv',sep=";")

# %%
df_deprem.tail(25)
# Out:
#        Tarih Enlem Boylam Derinlik  xM  MD  ML   Mw
# 17100   1905  39,8   30,5       22  55  53  53  5,5
# 17101   1905  40,2     29        6  57  54  54  5,7
# 17102   1905  39,6   27,9       15  53  50  49  5,3
# 17103   1904    38     27       30  48  47  46  4,8
# 17104   1904  38,4   27,2       20  58  56  56  5,8
# 17105   1904    38     27       30  60  58  57    6
# 17106   1904  37,4   26,6        5  47  46  46  4,7
# 17107   1904  37,7   26,9        6  62  59  59  6,1
# 17108   1904  38,4   27,2       20  55  53  53  5,5
# 17109   1904  40,3   38,4       30  53  50  50  5,3
# 17110   1904  37,8   29,1       20  49  48  48  4,9
# 17111   1903    35     30       20  58  55  55  5,8
# 17112   1903  41,1   44,4       22  47  46  46  4,7
# 17113   1903  41,4   44,5       30  52  49  49  5,2
# 17114   1903  37,8   32,5        5  44  44   0    0
# 17115   1903  40,9   42,8       16  55  53  53  5,5
# 17116   1903  38,7   41,5       30  52  49  49  5,2
# ...

# %%
df_deprem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17125 entries, 0 to 17124
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tarih     17125 non-null  int64
#  1   Enlem     17125 non-null  object
#  2   Boylam    17125 non-null  object
#  3   Derinlik  17125 non-null  object
#  4   xM        17125 non-null  int64
#  5   MD        17125 non-null  int64
#  6   ML        17125 non-null  int64
#  7   Mw        17125 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 1.0+ MB

# %%
i = 0
counter = 0
while i < 17125:
    if df_deprem.iloc[i,7] == "0" or df_deprem.iloc[i,7] == 0:
        df_deprem.iloc[i,7] = float(df_deprem.iloc[i,6]/10)
        counter = counter + 1
    i = i + 1
        
print(counter)
# Out:
# 12198

# %%
j = 0
counter2 = 0
while j < 17125:
    if df_deprem.iloc[j,7] == "0" or df_deprem.iloc[j,7] == 0:
        df_deprem.iloc[j,7] = float(df_deprem.iloc[j,5]/10)
        counter2 = counter2 + 1
    j = j + 1
        
print(counter2)
# Out:
# 8457

# %%
df_deprem.tail(10)
# Out:
#        Tarih Enlem Boylam Derinlik  xM  MD  ML   Mw
# 17115   1903  40,9   42,8       16  55  53  53  5,5
# 17116   1903  38,7   41,5       30  52  49  49  5,2
# 17117   1903  39,1   42,5       30  63  60  60  6,2
# 17118   1903    39     28       20  56  54  53  5,6
# 17119   1901  39,8   30,5       15  53  50  49  5,3
# 17120   1901  37,8   27,8       15  50  50   0    5
# 17121   1901  38,4   31,4        5  50  50   0    5
# 17122   1901  38,2   27,7        5  50  50   0    5
# 17123   1901  37,9   27,9       15  48  47  46  4,8
# 17124   1900  37,8   29,1        5  50  50   0    5

# %%
k = 0
counter3 = 0
while k < 17125:
    if df_deprem.iloc[k,7] == "0" or df_deprem.iloc[k,7] == 0:
        df_deprem.iloc[k,7] = float(df_deprem.iloc[k,4]/10)
        counter3 = counter3 + 1
    k = k + 1
        
print(counter3)
# Out:
# 2120

# %%
f = 0
counter4 = 0
while f < 17125:
    if df_deprem.iloc[f,7] == "0" or df_deprem.iloc[f,7] == 0:
        df_deprem.iloc[f,7] = float(df_deprem.iloc[f,4]/10)
        counter4 = counter4 + 1
    f = f + 1
        
print(counter4)
# Out:
# 0

# %%
file = open("deneme.txt","w",encoding="utf-8")

# %%
i = 0
while i < 17125:
    file.write(str(df_deprem.iloc[i,0]) + ";" + str(df_deprem.iloc[i,1]) + ";" + str(df_deprem.iloc[i,2]) + ";" +str(df_deprem.iloc[i,3]) + ";" + str(df_deprem.iloc[i,7]) + "\n")
    i = i + 1
file.close()

# %%
file.close()

# %%
df_deneme = pd.read_csv('deneme.csv',sep=";")

# %%
df_deneme.head()
# Out:
#    Tarih    Enlem   Boylam Derinlik   Mw
# 0   2020  39,6762  27,8122      5,5  3,7
# 1   2020  35,5632   31,606        5  3,6
# 2   2020  39,0075  35,8543        5  3,4
# 3   2020  38,1787  38,6887      8,2  4,1
# 4   2020  39,0807  27,6843      7,5  3,5

# %%
df_deneme.tail(25)
# Out:
#        Tarih Enlem Boylam Derinlik   Mw
# 17100   1905  39,8   30,5       22  5,5
# 17101   1905  40,2     29        6  5,7
# 17102   1905  39,6   27,9       15  5,3
# 17103   1904    38     27       30  4,8
# 17104   1904  38,4   27,2       20  5,8
# 17105   1904    38     27       30    6
# 17106   1904  37,4   26,6        5  4,7
# 17107   1904  37,7   26,9        6  6,1
# 17108   1904  38,4   27,2       20  5,5
# 17109   1904  40,3   38,4       30  5,3
# 17110   1904  37,8   29,1       20  4,9
# 17111   1903    35     30       20  5,8
# 17112   1903  41,1   44,4       22  4,7
# 17113   1903  41,4   44,5       30  5,2
# 17114   1903  37,8   32,5        5  4.4
# 17115   1903  40,9   42,8       16  5,5
# 17116   1903  38,7   41,5       30  5,2
# 17117   1903  39,1   42,5       30  6,2
# 17118   1903    39     28       20  5,6
# 17119   1901  39,8   30,5       15  5,3
# 17120   1901  37,8   27,8       15  5.0
# 17121   1901  38,4   31,4        5  5.0
# ...

# %%
v = 0
while v < 17125:
    test = df.iloc[v,4].replace(",",".")
    print(test)
    v = v + 1
# Out:
# 3.7
# 3.6
# 3.4
# 4.1
# 3.5
# 3.4
# 4
# 3.5
# 3.8
# 3.6
# 4.4
# 3.6
# 3.6
# 3.8
# 3.5
# 4.8
# 4.8
# 4.5
# 4
# 5.7
# 3.4
# 3.7
# 4
# 4
# 3.5
# 3.6
# 4
# 4.1
# 3.6
# 3.5
# 3.5
# 3.9
# 4
# 3.5
# 3.5
# 4.6
# 4.4
# 3.5
# 3.5
# 3.8
# 3.5
# 3.8
# 3.9
# 3.8
# 4
# 3.6
# 3.4
# 3.6
# 4.4
# 3.4
# 3.5
# 3.5
# 3.6
# 4.1
# 3.5
# 3.5
# 4.1
# 4
# 4
# 3.9
# 4.5
# 3.5
# 3.6
# 3.4
# 3.8
# 3.9
# 3.5
# 4.2
# 4
# 4
# 3.5
# 4.7
# 5.2
# 3.5
# 4.4
# 3.9
# 3.8
# 3.7
# 4
# 3.5
# 3.5
# 4.7
# 3.8
# 3.7
# 4.2
# 3.5
# 5.2
# 5.4
# 3.8
# 3.7
# 4.2
# 3.5
# 4
# 3.7
# 4.2
# 4
# 4.4
# 3.9
# 4
# 4.1
# 5.5
# 3.7
# 3.8
# 3.9
# 3.7
# 3.5
# 4.7
# 4.5
# 5.9
# 3.7
# 3.5
# 3.6
# 3.5
# 3.7
# 5.3
# 4.3
# 3.8
# 3.6
# 3.9
# 4.1
# 4
# 4
# 3.5
# 3.5
# 4
# 3.9
# 4
# 4.5
# 4.3
# 3.8
# 4
# 4.2
# 3.7
# 3.7
# 3.9
# 4.1
# 3.6
# 4.1
# 3.9
# 3.5
# 3.8
# 3.5
# 3.5
# 3.5
# 3.5
# 4
# 3.7
# 4.1
# 3.8
# 3.2
# 4.4
# 3.4
# 4.1
# 3.7
# 3.6
# 3.6
# 4
# 3.6
# 3.8
# 4
# 3.5
# 4.1
# 3.8
# 4.5
# 4.3
# 3.8
# 3.5
# 3.8
# 3.5
# 4.2
# 3.9
# 3.6
# 4.2
# 4.1
# ...
